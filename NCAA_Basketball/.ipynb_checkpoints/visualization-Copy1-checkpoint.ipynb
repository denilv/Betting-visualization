# %% [markdown]
# # Betting visualization and search for similar games
# ### Denisov Ilia

# %%
import numpy as np
import pylab as pl
import pandas as pd
# %pylab inline
from datetime import datetime
from collections import Counter
import matplotlib.mlab as mlab
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics.pairwise import pairwise_distances
np.set_printoptions(precision=2, threshold=5)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Preparing a dataset
# Using Hamid Sardar's NCAA Basketball dataset for 2012-2017 seasons.

# %%
df_raw = pd.read_csv('seeds/inputs.csv')
df_raw = df_raw.fillna(0)
df = df_raw.iloc[::2]
df = df.reset_index()
delete_columns = ['week', 'game_id', 'season', 'index', 'team_org', 'opponent_team_org', 'win_against_spread']
df = df.drop(delete_columns, axis=1)

dates = np.array(df.date)
dates = [datetime.strptime(str(i), '%Y%m%d').date() for i in dates]
#add seasons
seasons = [i.year for i in dates]
#add weeknums
weeknums = [i.isocalendar()[1] for i in dates]
#add week day
weekdays = [i.weekday() for i in dates]
#add time
hours = []
for i in df.time:
    if i[-1] == 'p':
        hours.append(12+int(i.split(':')[0]))
    else:
        hours.append(int(i.split(':')[0]))
#add win/lose
winloses = [1 if i>0 else 0 for i in df.points_difference]

df.insert(1, 'winlose', winloses)
df.insert(1, 'hour', hours)
df.insert(1, 'weekday', weekdays)
df.insert(1, 'weeknum', weeknums)
df.insert(1, 'season', seasons)

df = df.drop(['date', 'time'], axis=1)
df.head()
# Out:
#    season  weeknum  weekday  hour  winlose  team opponent_team  points  \
# 0    2012       45        4    17        0   MSU          CONN      62
# 1    2012       45        4    19        0  GAST          DUKE      55
# 2    2012       45        4    21        0    LT          TXAM      59
# 3    2012       45        4    20        0    MD            UK      69
# 4    2012       45        4    23        0  INST          UCLA      59
#
#    opponent_points  points_difference  spread  spread_percentage_sbr  \
# 0               66                 -4    -8.0                     55
# 1               74                -19    19.5                     40
# 2               71                -12     7.5                     52
# 3               72                 -3    10.5                     61
# 4               86                -27    14.0                     47
#
#    moneyline_team  moneyline_opponent  total_team  total_opponent  \
# 0          -355.0               320.0       133.0           133.0
# 1             0.0                 0.0       132.5           132.5
# 2           290.0              -350.0       133.0           133.0
# 3           485.0              -575.0       135.5           135.5
# 4           900.0             -1100.0       132.5           132.5
#
#    spread_percentage_sportsplays  spread_percentage_vegas
# 0                           75.0                     69.0
# 1                           15.0                     25.0
# 2                           22.0                     76.0
# 3                           32.0                     64.0
# 4                           24.0                     42.0

# %% [markdown]
# ## Data standardization

# %%
distance_features = ['spread', 'spread_percentage_sbr', 'moneyline_team',\
       'moneyline_opponent', 'total_team', 'total_opponent',\
       'spread_percentage_sportsplays', 'spread_percentage_vegas']

# %%
for column in distance_features:
    for perc in (50, 90, 99):
        val = np.percentile(np.abs(df[column]), perc)
        print('{} percintile is {} for {} column.'.format(perc, val, column.upper()))
    print()
# Out:
# 50 percintile is 6.5 for SPREAD column.
# 90 percintile is 15.0 for SPREAD column.
# 99 percintile is 26.5 for SPREAD column.
#
# 50 percintile is 50.0 for SPREAD_PERCENTAGE_SBR column.
# 90 percintile is 61.0 for SPREAD_PERCENTAGE_SBR column.
# 99 percintile is 68.0 for SPREAD_PERCENTAGE_SBR column.
#
# 50 percintile is 240.0 for MONEYLINE_TEAM column.
# 90 percintile is 1150.0 for MONEYLINE_TEAM column.
# 99 percintile is 9000.0 for MONEYLINE_TEAM column.
#
# 50 percintile is 250.0 for MONEYLINE_OPPONENT column.
# 90 percintile is 1450.0 for MONEYLINE_OPPONENT column.
# 99 percintile is 23000.0 for MONEYLINE_OPPONENT column.
#
# 50 percintile is 139.0 for TOTAL_TEAM column.
# 90 percintile is 154.0 for TOTAL_TEAM column.
# 99 percintile is 169.0 for TOTAL_TEAM column.
#
# 50 percintile is 139.0 for TOTAL_OPPONENT column.
# 90 percintile is 154.0 for TOTAL_OPPONENT column.
# 99 percintile is 169.0 for TOTAL_OPPONENT column.
#
# 50 percintile is 47.0 for SPREAD_PERCENTAGE_SPORTSPLAYS column.
# 90 percintile is 71.0 for SPREAD_PERCENTAGE_SPORTSPLAYS column.
# 99 percintile is 84.0 for SPREAD_PERCENTAGE_SPORTSPLAYS column.
#
# 50 percintile is 50.0 for SPREAD_PERCENTAGE_VEGAS column.
# 90 percintile is 77.0 for SPREAD_PERCENTAGE_VEGAS column.
# 99 percintile is 92.0 for SPREAD_PERCENTAGE_VEGAS column.

# %%
dfv2 = df.copy()
for column in distance_features:
    val = np.percentile(np.abs(df[column]), 99)
    dfv2 = dfv2[np.abs(dfv2[column]) < val]

# %%
print(len(dfv2), len(df))
# Out:
# 15837 16751

# %% [markdown]
# ## Find of the most correlated features

# %%
def find_correlated_features(x, features):
    # replace this code to find really correlated features
    corr_matrix = abs(np.corrcoef(x.T))
    c = Counter()
    for i, feature_i in enumerate(features):
        for j, feature_j in enumerate(features):
            c['{} + {}'.format(feature_i, feature_j)] =  corr_matrix[i,j]
            if i < j and  corr_matrix[i,j] > 0.3:
                print("Correlated features: %s + %s -> %.2f" % (feature_i, feature_j, corr_matrix[i,j]))
#     print(c.most_common(20))

# %%
df.columns
# Out:
# Index(['season', 'weeknum', 'weekday', 'hour', 'winlose', 'team',
#        'opponent_team', 'points', 'opponent_points', 'points_difference',
#        'spread', 'spread_percentage_sbr', 'moneyline_team',
#        'moneyline_opponent', 'total_team', 'total_opponent',
#        'spread_percentage_sportsplays', 'spread_percentage_vegas'],
#       dtype='object')

# %%
#['season', 'weeknum', 'weekday', 'hour', 'winlose',\
features = ['points', 'opponent_points', 'points_difference',\
            'spread', 'spread_percentage_sbr', 'moneyline_team',\
            'moneyline_opponent', 'total_team', 'total_opponent',\
            'spread_percentage_sportsplays', 'spread_percentage_vegas']
x = df[features].values

# %%
find_correlated_features(x, features)
# Out:
# Correlated features: points + opponent_points -> 0.42
# Correlated features: points + points_difference -> 0.52
# Correlated features: points + spread -> 0.31
# Correlated features: points + total_team -> 0.41
# Correlated features: points + total_opponent -> 0.41
# Correlated features: opponent_points + points_difference -> 0.55
# Correlated features: opponent_points + spread -> 0.34
# Correlated features: opponent_points + total_team -> 0.44
# Correlated features: opponent_points + total_opponent -> 0.44
# Correlated features: points_difference + spread -> 0.61
# Correlated features: points_difference + moneyline_team -> 0.37
# Correlated features: points_difference + moneyline_opponent -> 0.30
# Correlated features: points_difference + spread_percentage_sportsplays -> 0.33
# Correlated features: spread + spread_percentage_sbr -> 0.36
# Correlated features: spread + moneyline_team -> 0.57
# Correlated features: spread + moneyline_opponent -> 0.46
# Correlated features: spread + spread_percentage_sportsplays -> 0.55
# Correlated features: spread + spread_percentage_vegas -> 0.37
# Correlated features: spread_percentage_sbr + spread_percentage_sportsplays -> 0.56
# Correlated features: spread_percentage_sbr + spread_percentage_vegas -> 0.48
# Correlated features: moneyline_team + moneyline_opponent -> 0.95
# Correlated features: total_team + total_opponent -> 1.00
# Correlated features: spread_percentage_sportsplays + spread_percentage_vegas -> 0.51

# %%
pl.figure(figsize=[11.7,10])
hb = pl.hexbin(df['points'], df['opponent_points'], gridsize=30, cmap='inferno', extent=[40, 100, 40, 100])
pl.xlabel('Team points')
pl.ylabel('Oppenent points')
pl.title('Points 2D histogram by count of games')
pl.colorbar()
pl.show()

# %%
for i, f in enumerate(features):
    plt.subplot(4, 3,i+1)
    fig = plt.gcf()
    fig.set_size_inches(20,20)
    sns.distplot(df[f], kde=False)
    plt.xlim(0)
    plt.xticks(rotation=45)
plt.show()

# %%
pts_diff = np.array(df['moneyline_team'])
pl.figure(figsize=[10,10])
n, bins, patches = pl.hist(pts_diff, bins=66, edgecolor='black', rwidth=0.7, range=(-2000, 2000))
pl.grid(True)
pl.show()

# %%
pts_diff = np.array(df['moneyline_opponent'])
pl.figure(figsize=[10,10])
n, bins, patches = pl.hist(pts_diff, bins=66, edgecolor='black', rwidth=0.7, range=(-2000, 2000))
pl.grid(True)
pl.show()

# %%
pts_diff = np.array(df['points_difference'])
pts_diff = np.abs(pts_diff)[pts_diff!=0]
pl.figure(figsize=[10,10])
n, bins, patches = pl.hist(pts_diff, bins=66, edgecolor='black', range=(-1, 65), rwidth=0.7)
pl.title('Points difference histogram')
pl.xlabel('Points difference')
pl.ylabel('Frequency')
# pl.xticks(range(-70,70,2))
pl.grid(True)
pl.show()

# %%
x = df.points_difference
y = df.spread
sns.jointplot(x=x, y=y, kind='hex', size=10)
pl.show()

# %% [markdown]
# # Get most similiar games

# %%
distance_features = ['spread', 'spread_percentage_sbr', 'moneyline_team',\
       'moneyline_opponent', 'total_team', 'total_opponent',\
       'spread_percentage_sportsplays', 'spread_percentage_vegas']

# %% [markdown]
# Get top 10 closest games to given game by all distance_features (using Eucleadean metric).

# %%
def get_similar_games(games, top=1000):
    dists = pairwise_distances(games)
    result = []
    for d in dists:
        args = d.argsort()
        similar_games = df.iloc[args[:top]]
        similar_games.insert(0, 'distance', d[args[:top]])
        result.append(similar_games)
    return result

# %%
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(np.array(df[distance_features].values))
similar_games = get_similar_games(scaled_features)

# %% [markdown]
# The first game is a game with a minimum distance of 0, i.e. the game itself, for which we are looking for similar games.

# %% [markdown]
# First selected game of 2017 NCAA Basketball season.

# %%
def get_crossval_score():
    pos = 0
    a = int(21414 / 2)
    print(a)
    b = int(29240 / 2)
    print(b)
#     a = int(29240 / 2)
#     print(a)
#     b = int(33500 / 2)
#     print(b)
    try:
        for _id in range(a, b):
            tmp = similar_games[_id].iloc[0]
            season = tmp.season
            week = tmp.weeknum
    #         print(tmp)
            tmp1 = similar_games[_id][np.logical_and(similar_games[_id].season <= 2017,\
                                                                   similar_games[_id].weeknum <= week)]
    #         print(len(similar_games[_id]))
    #         print(similar_games[_id])
            if (len(tmp1) < 2):
                continue
            av = np.average(tmp1.points_difference[1:], weights=tmp1.distance[1:])
            if np.sign(av) == np.sign(tmp1.points_difference.iloc[0]):
                pos += 1
        print(pos/(b-a))
    except:
        print(tmp1)
get_crossval_score()
# Out:
# 10707
# 14620
# 0.717607973421927

# %%
def get_crossval_score(year=2017, top=30):
    games = []
    for game in similar_games:
        if game.iloc[0].season == year:
            games.append(game)
    pos = 0
    for game in games:
        season = game.iloc[0].season
        week = game.iloc[0].weeknum
        tmp1 = game[np.logical_and(game.season <= season,\
                                   game.weeknum <= week)]
        weighted_av = np.average(tmp1.points_difference[1:top], weights=tmp1.distance[1:top])
        if np.sign(weighted_av) == np.sign(tmp1.points_difference.iloc[0]):
            pos += 1
    return pos / len(games)

# %%
for year in (2015, 2016, 2017):
    for top in (10, 20, 25, 30, 50, 75, 100):
        score = get_crossval_score(year, top)
        print('Crossvall accuracy score {:.4f}, {:d} year, using top {:<3} closest games to compute result.'.\
              format(score, year, top))
    print()
# Out:
# Crossvall accuracy score 0.7082, 2015 year, using top 10  closest games to compute result.
# Crossvall accuracy score 0.7258, 2015 year, using top 20  closest games to compute result.
# Crossvall accuracy score 0.7266, 2015 year, using top 25  closest games to compute result.
# Crossvall accuracy score 0.7209, 2015 year, using top 30  closest games to compute result.
# Crossvall accuracy score 0.7288, 2015 year, using top 50  closest games to compute result.
# Crossvall accuracy score 0.7283, 2015 year, using top 75  closest games to compute result.
# Crossvall accuracy score 0.7255, 2015 year, using top 100 closest games to compute result.
#
# Crossvall accuracy score 0.7013, 2016 year, using top 10  closest games to compute result.
# Crossvall accuracy score 0.7218, 2016 year, using top 20  closest games to compute result.
# Crossvall accuracy score 0.7259, 2016 year, using top 25  closest games to compute result.
# Crossvall accuracy score 0.7218, 2016 year, using top 30  closest games to compute result.
# Crossvall accuracy score 0.7246, 2016 year, using top 50  closest games to compute result.
# Crossvall accuracy score 0.7256, 2016 year, using top 75  closest games to compute result.
# Crossvall accuracy score 0.7253, 2016 year, using top 100 closest games to compute result.
#
# Crossvall accuracy score 0.6917, 2017 year, using top 10  closest games to compute result.
# Crossvall accuracy score 0.7030, 2017 year, using top 20  closest games to compute result.
# Crossvall accuracy score 0.7091, 2017 year, using top 25  closest games to compute result.
# Crossvall accuracy score 0.7039, 2017 year, using top 30  closest games to compute result.
# Crossvall accuracy score 0.7006, 2017 year, using top 50  closest games to compute result.
# Crossvall accuracy score 0.7020, 2017 year, using top 75  closest games to compute result.
# Crossvall accuracy score 0.7058, 2017 year, using top 100 closest games to compute result.

# %%
def get_report(_id):
    print('Weighted average points_difference for simillar games', \
          np.average(similar_games[_id].points_difference[1:], weights=similar_games[_id].distance[1:]))
    print('Average points_difference for simillar games', \
          np.average(similar_games[_id].points_difference[1:]))
    pl.figure(figsize=[10,10])
    x = df.points_difference
    y = df.spread
    pl.scatter(x, y, c='lightblue', s=5, )
    x1 = similar_games[_id].points_difference
    y1 = similar_games[_id].spread
    pl.scatter(x1, y1, c='red', s=10)
    plt.xlim(-50,  40)
    plt.ylim(-20, 30)
    pl.xlabel('Points difference')
    pl.ylabel('Spred')
    pl.title('Show on the scatter the nearest games to the given 3 games of 2017 season NCAA Basketball (indices: 16500 (red), 16450 (black), 16600 (green))')
    pl.show()

# %%
_id = np.random.randint(16000, 16700)
similar_games[_id]
# Out:
#        distance  season  weeknum  weekday  hour  winlose  team opponent_team  \
# 16315  0.000000    2017        8        2    19        0   UNI          INST
# 5256   0.024834    2014        7        2    19        1   SYR          PITT
# 6450   0.042018    2014       13        4    20        1   MSU           UVA
# 15047  0.044200    2017        2        5    16        1    LT           ODU
# 12279  0.044683    2016        7        1    19        1  BALL          M-OH
# 3456   0.045323    2013       49        2    19        1   WIS           UVA
# 6713   0.047781    2014       49        2    23        0  WICH          UTAH
# 7532   0.051937    2015        3        5    18        1  TENN          MIZZ
# 16565  0.052606    2017        9        2    19        1    GW           FOR
# 9003   0.058087    2015       10        2    23        1   ORE          ORST
# 9054   0.060995    2015       10        4    19        1   NIU          BALL
# 1432   0.062013    2013        6        1    19        1   PUR           PSU
# 7581   0.064800    2015        3        6    18        0  L-IL           SIU
# 2382   0.065013    2013       10        2    19        0  GTWN          VILL
# 6552   0.065079    2014       47        4    24        1   USC          DREX
# 385    0.067453    2012       52        6    19        0   DAY           USC
# 8702   0.068020    2015        8        6    19        1   MSU           ILL
# 7931   0.069715    2015        5        4    20        1  YALE          CLMB
# 995    0.069764    2013        4        1    19        1   MSU           WIS
# 4295   0.069848    2014        2        5    21        1   SAC           SUU
# 14378  0.071183    2016       51        2    22        1   UVA           CAL
# 12015  0.073288    2016        6        0    19        0  OKST           TCU
# 8949   0.073401    2015       10        0    19        0   BAY           TEX
# 6121   0.073430    2014       10        6    13        1   SYR           FSU
# 1838   0.073511    2013        7        5    19        1   ORE           WSU
# 9148   0.076038    2015       10        6    15        1   WIS           OSU
# 5525   0.076204    2014        8        3    19        1  TOWS            NE
# 3515   0.076363    2013       49        5    17        0   UVA            GB
# 5217   0.076988    2014        6        6    16        1   WMU           NIU
# 5729   0.077156    2014        9        2    21        0   NEB           ILL
# ...         ...     ...      ...      ...   ...      ...   ...           ...
# 7908   0.161359    2015        5        3    22        1  LBSU           CSF
# 8326   0.161422    2015        7        2    19        1   SYR            BC
# 11519  0.161489    2016        3        6    19        0   SYR           UVA
# 8742   0.161514    2015        9        2    19        0  VALP           DET
# 15159  0.161521    2017        3        2    20        0   MIA          WAKE
# 8677   0.161570    2015        8        5    17        0  TNST          JVST
# 8198   0.161585    2015        6        5    16        0   SLU           FOR
# 16218  0.161602    2017        7        5    19        0  CLMB          DART
# 1662   0.161612    2013        7        0    19        0  MARQ          GTWN
# 2547   0.161638    2013       10        5    17        0  ILST          WICH
# 13867  0.161676    2016       48        0    20        1  TLSA           ORU
# 1159   0.161771    2013        4        5    22        1   CSU          FRES
# 12648  0.161865    2016        8        5    14        0   APP          GAST
# 9002   0.161883    2015       10        2    23        1  SDSU          UNLV
# 5631   0.161948    2014        8        5    20        0  MIZZ           ALA
# 4532   0.162114    2014        3        5    22        0   EWU           SAC
# 6587   0.162122    2014       48        0    14        0   PUR           KSU
# 7962   0.162176    2015        5        5    14        0   LSU          MSST
# 12579  0.162198    2016        8        3    20        1  RICE           USM
# 5278   0.162361    2014        7        2    23        1   CAL           WSU
# 10231  0.162440    2015       50        2    20        1   DEP          DRKE
# 7069   0.162452    2015        1        5    20        1   UNC          CLEM
# 11487  0.162452    2016        3        5    16        0   WOF           FUR
# 698    0.162778    2013        2        3    22        0   SAC          PRST
# 7045   0.162780    2015        1        4    20        0  IPFW           WIU
# 7046   0.162780    2015        1        4    20        0  IPFW           WIU
# 7044   0.162780    2015        1        4    20        0  IPFW           WIU
# 8582   0.162789    2015        8        3    19        1   UNT           FAU
# 12540  0.162846    2016        8        2    19        0   UGA           AUB
# 2129   0.162890    2013        9        1    19        0   IND          MINN
#
#        points  opponent_points  points_difference  spread  \
# 16315      59               69                -10     1.0
# 5256       58               56                  2     1.5
# 6450       61               59                  2     2.5
# 15047      75               63                 12     1.0
# 12279      73               56                 17    -1.0
# 3456       48               38                 10     4.0
# 6713       68               69                 -1     3.0
# 7532       59               51                  8    -1.0
# 16565      67               66                  1    -2.0
# 9003       65               62                  3    -1.0
# 9054       71               67                  4    -1.5
# 1432       58               49                  9    -2.5
# 7581       52               59                 -7     1.0
# 2382       57               67                -10    -1.0
# 6552       72               70                  2    -1.5
# 385        61               63                 -2     3.0
# 8702       60               53                  7    -3.0
# 7931       63               59                  4    -1.0
# 995        49               47                  2     5.0
# 4295       77               49                 28    -2.5
# 14378      56               52                  4    -2.5
# 12015      56               63                 -7    -2.0
# 8949       59               61                 -2     4.0
# 6121       74               58                 16    -3.0
# 1838       79               77                  2    -4.0
# 9148       72               48                 24    -2.5
# 5525       79               70                  9     1.0
# 3515       72               75                 -3    -3.0
# 5217       74               71                  3    -3.0
# 5729       49               60                -11     3.5
# ...       ...              ...                ...     ...
# 7908       91               85                  6    -6.5
# 8326       70               56                 14    -2.0
# 11519      65               73                 -8     9.5
# 8742       60               63                 -3    -4.5
# 15159      79               96                -17    -1.5
# 8677       50               55                 -5     7.0
# 8198       65               83                -18     1.0
# 16218      79               80                 -1    -4.0
# 1662       55               63                 -8     4.5
# 2547       51               66                -15     2.5
# 13867      79               65                 14    -2.5
# 1159       74               63                 11    -7.0
# 12648      70               83                -13     9.0
# 9002       60               58                  2    -5.0
# 5631       73               80                 -7     1.0
# 4532       64               75                -11    -2.5
# 6587       79               88                 -9    -1.5
# 7962       67               73                 -6    -4.5
# 12579      76               74                  2    -3.0
# 5278       80               76                  4    -6.0
# 10231      74               71                  3    -2.0
# 7069       74               50                 24    -6.5
# 11487      62               63                 -1     4.0
# 698        69               87                -18     4.5
# 7045       67               73                 -6    -3.0
# 7046       67               73                 -6    -3.0
# 7044       67               73                 -6    -3.0
# 8582       79               72                  7     2.0
# 12540      81               84                 -3    -5.5
# 2129       73               77                 -4    -4.5
#
#        spread_percentage_sbr  moneyline_team  moneyline_opponent  total_team  \
# 16315                     59           103.0              -113.0       123.0
# 5256                      58           110.0              -120.0       124.0
# 6450                      57          -145.0               135.0       125.5
# 15047                     58           100.0              -120.0       123.0
# 12279                     56          -119.0              -101.0       124.5
# 3456                      58           165.0              -175.0       124.0
# 6713                      58           145.0              -155.0       128.0
# 7532                      56          -105.0              -105.0       125.0
# 16565                     59          -135.0               115.0       127.0
# 9003                      60          -112.0               102.0       125.0
# 9054                      64          -125.0               105.0       123.5
# 1432                      59          -140.0               130.0       125.0
# 7581                      57          -105.0              -105.0       117.0
# 2382                      58          -105.0              -105.0       123.0
# 6552                      56          -125.0               115.0       120.0
# 385                       58           150.0              -160.0       127.0
# 8702                      59          -150.0               140.0       127.0
# 7931                      55          -112.0               102.0       118.0
# 995                       57           200.0              -220.0       122.5
# 4295                      62          -140.0               130.0       125.0
# 14378                     59          -140.0               120.0       117.5
# 12015                     55          -135.0               120.0       128.5
# 8949                      57           160.0              -170.0       128.5
# 6121                      59          -155.0               145.0       125.5
# 1838                      58          -170.0               160.0       126.0
# 9148                      57          -138.0               128.0       129.0
# 5525                      59           102.0              -112.0       131.5
# 3515                      57          -140.0               130.0       129.5
# 5217                      57          -150.0               140.0       121.0
# 5729                      59           135.0              -155.0       124.5
# ...                      ...             ...                 ...         ...
# 7908                      53          -280.0               255.0       134.5
# 8326                      50          -130.0               120.0       133.0
# 11519                     63           415.0              -525.0       125.5
# 8742                      59          -200.0               170.0       139.0
# 15159                     54          -122.0               112.0       141.5
# 8677                      65           260.0              -290.0       122.5
# 8198                      48           103.0              -113.0       131.0
# 16218                     54          -185.0               160.0       140.0
# 1662                      52           190.0              -210.0       123.0
# 2547                      61           130.0              -140.0       138.0
# 13867                     63          -142.0               132.0       141.5
# 1159                      48          -305.0               275.0       120.5
# 12648                     63           360.0              -450.0       138.0
# 9002                      52          -200.0               185.0       120.5
# 5631                      61           105.0              -115.0       136.0
# 4532                      60          -135.0               125.0       141.5
# 6587                      60          -125.0               105.0       133.0
# 7962                      57          -185.0               170.0       136.5
# 12579                     54          -155.0               135.0       142.0
# 5278                      60          -260.0               240.0       130.5
# 10231                     52          -135.0               115.0       141.0
# 7069                      56          -300.0               270.0       132.5
# 11487                     63           160.0              -185.0       133.5
# 698                       60           170.0              -200.0       135.0
# 7045                      66          -150.0               140.0       136.0
# 7046                      66          -150.0               140.0       136.0
# 7044                      66          -150.0               140.0       136.0
# 8582                      50           115.0              -125.0       128.0
# 12540                     59          -240.0               200.0       137.5
# 2129                      61          -190.0               175.0       139.0
#
#        total_opponent  spread_percentage_sportsplays  spread_percentage_vegas
# 16315           123.0                           74.0                     62.0
# 5256            124.0                           74.0                     65.0
# 6450            125.5                           71.0                     60.0
# 15047           123.0                           72.0                     56.0
# 12279           124.5                           75.0                     60.0
# 3456            124.0                           72.0                     61.0
# 6713            128.0                           73.0                     61.0
# 7532            125.0                           71.0                     65.0
# 16565           127.0                           72.0                     63.0
# 9003            125.0                           75.0                     69.0
# 9054            123.5                           74.0                     61.0
# 1432            125.0                           79.0                     64.0
# 7581            117.0                           76.0                     68.0
# 2382            123.0                           77.0                     70.0
# 6552            120.0                           68.0                     62.0
# 385             127.0                           68.0                     67.0
# 8702            127.0                           70.0                     61.0
# 7931            118.0                           70.0                     59.0
# 995             122.5                           70.0                     58.0
# 4295            125.0                           70.0                     66.0
# 14378           117.5                           71.0                     58.0
# 12015           128.5                           71.0                     61.0
# 8949            128.5                           68.0                     62.0
# 6121            125.5                           71.0                     68.0
# 1838            126.0                           74.0                     60.0
# 9148            129.0                           70.0                     59.0
# 5525            131.5                           78.0                     67.0
# 3515            129.5                           74.0                     64.0
# 5217            121.0                           67.0                     63.0
# 5729            124.5                           73.0                     72.0
# ...               ...                            ...                      ...
# 7908            134.5                           64.0                     64.0
# 8326            133.0                           61.0                     54.0
# 11519           125.5                           68.0                     76.0
# 8742            139.0                           74.0                     74.0
# 15159           141.5                           68.0                     69.0
# 8677            122.5                           57.0                     69.0
# 8198            131.0                           59.0                     62.0
# 16218           140.0                           71.0                     70.0
# 1662            123.0                           54.0                     60.0
# 2547            138.0                           58.0                     57.0
# 13867           141.5                           75.0                     71.0
# 1159            120.5                           68.0                     64.0
# 12648           138.0                           72.0                     59.0
# 9002            120.5                           57.0                     58.0
# 5631            136.0                           74.0                     81.0
# 4532            141.5                           68.0                     71.0
# 6587            133.0                           59.0                     76.0
# 7962            136.5                           73.0                     77.0
# 12579           142.0                           79.0                     64.0
# 5278            130.5                           81.0                     78.0
# 10231           141.0                           69.0                     67.0
# 7069            132.5                           61.0                     55.0
# 11487           133.5                           65.0                     79.0
# 698             135.0                           56.0                     67.0
# 7045            136.0                           68.0                     75.0
# 7046            136.0                           68.0                     75.0
# 7044            136.0                           68.0                     75.0
# 8582            128.0                           56.0                     68.0
# 12540           137.5                           63.0                     68.0
# 2129            139.0                           75.0                     74.0
#
# [1000 rows x 19 columns]

# %%
get_report(_id)
# Out:
# Weighted average points_difference for simillar games 0.97675347323
# Average points_difference for simillar games 0.932932932933

# %%
print('Weighted average points_difference for simillar games', \
      np.average(similar_games[16500].points_difference[1:], weights=similar_games[16500].distance[1:]))
print('Average points_difference for simillar games', \
      np.average(similar_games[16500].points_difference[1:]))
# Out:
# Weighted average points_difference for simillar games -5.41363956131
# Average points_difference for simillar games -5.26315789474

# %% [markdown]
# Second selected game of 2017 NCAA Basketball season.

# %%
similar_games[16600]
# Out:
#        distance  season  weeknum  weekday  hour  winlose  team opponent_team  \
# 16600  0.000000    2017        9        3    20        1  CHAR          UTSA
# 12176  0.025270    2016        6        5    16        0    GW          SBON
# 5759   0.031763    2014        9        3    22        0   CSN           CSF
# 13039  0.033097    2016       10        2    18        0   UNO          SELA
# 11716  0.038139    2016        4        5    20        0  PENN          BRWN
# 11370  0.040431    2016        3        3    20        1   HOF            NE
# 14632  0.045018    2017       52        6    16        0  MARQ          HALL
# 16307  0.045289    2017        8        1    21        1  MISS          MSST
# 13206  0.046816    2016       11        2    18        0  ARMY          NJIT
# 1989   0.047211    2013        8        3    19        1  UNCG          CHAT
# 15921  0.047791    2017        6        3    19        0   SAM           WOF
# 10151  0.048287    2015       49        5    21        1   UTA          UTEP
# 13329  0.048575    2016       45        4    18        0   VAN          MARQ
# 4780   0.048726    2014        5        0    22        0   EWU          PRST
# 12033  0.048745    2016        6        1    19        1   TOL          BUFF
# 4371   0.048754    2014        3        2    21        0   LSU          MISS
# 13504  0.049087    2016       46        3    21        1  MICH          MARQ
# 14731  0.049268    2017        1        3    21        0  IOWA           NEB
# 1657   0.050856    2013        6        6    14        1   CAN          NIAG
# 11514  0.051249    2016        3        6    14        1   SIE           CAN
#
#        points  opponent_points  points_difference  spread  \
# 16600      76               75                  1     1.5
# 12176      57               64                 -7     2.5
# 5759       81               82                 -1     3.5
# 13039      74               84                -10     2.0
# 11716      83               89                 -6     1.5
# 11370      96               92                  4     3.5
# 14632      66               69                 -3     3.5
# 16307      87               82                  5     2.5
# 13206      65               79                -14     3.5
# 1989       94               68                 26     2.0
# 15921     127              131                 -4     4.5
# 10151      76               62                 14     1.5
# 13329      71               95                -24     2.0
# 4780       83               92                 -9     1.0
# 12033      71               69                  2     2.0
# 4371       74               88                -14     3.0
# 13504      79               61                 18     0.0
# 14731      90               93                 -3     2.5
# 1657       77               70                  7     4.5
# 11514      99               78                 21     2.5
#
#        spread_percentage_sbr  moneyline_team  moneyline_opponent  total_team  \
# 16600                     44           115.0              -125.0       150.0
# 12176                     45           130.0              -140.0       148.5
# 5759                      45           145.0              -165.0       148.5
# 13039                     45           115.0              -125.0       147.0
# 11716                     46           105.0              -125.0       148.0
# 11370                     46           145.0              -165.0       151.5
# 14632                     45           140.0              -160.0       154.5
# 16307                     42           123.0              -143.0       151.5
# 13206                     42           150.0              -160.0       154.0
# 1989                      47           120.0              -130.0       147.0
# 15921                     44           185.0              -200.0       150.5
# 10151                     46           108.0              -118.0       145.5
# 13329                     42           120.0              -130.0       150.0
# 4780                      44           102.0              -112.0       149.5
# 12033                     44           113.0              -133.0       150.0
# 4371                      42           130.0              -140.0       148.0
# 13504                     41           110.0              -120.0       147.0
# 14731                     43           130.0              -150.0       149.0
# 1657                      43           180.0              -195.0       148.0
# 11514                     48           120.0              -140.0       149.0
#
#        total_opponent  spread_percentage_sportsplays  spread_percentage_vegas
# 16600           150.0                           35.0                     26.0
# 12176           148.5                           34.0                     24.0
# 5759            148.5                           36.0                     26.0
# 13039           147.0                           36.0                     23.0
# 11716           148.0                           32.0                     29.0
# 11370           151.5                           37.0                     28.0
# 14632           154.5                           36.0                     27.0
# 16307           151.5                           37.0                     31.0
# 13206           154.0                           37.0                     26.0
# 1989            147.0                           31.0                     27.0
# 15921           150.5                           33.0                     29.0
# 10151           145.5                           32.0                     29.0
# 13329           150.0                           30.0                     22.0
# 4780            149.5                           34.0                     33.0
# 12033           150.0                           30.0                     21.0
# 4371            148.0                           37.0                     21.0
# 13504           147.0                           38.0                     24.0
# 14731           149.0                           32.0                     32.0
# 1657            148.0                           33.0                     29.0
# 11514           149.0                           34.0                     22.0

# %%
print('Weighted average points_difference for simillar games', \
      np.average(similar_games[16600].points_difference[1:], weights=similar_games[16600].distance[1:]))
print('Average points_difference for simillar games', \
      np.average(similar_games[16600].points_difference[1:]))
# Out:
# Weighted average points_difference for simillar games 0.616031164765
# Average points_difference for simillar games 0.105263157895

# %% [markdown]
# Third selected game of 2017 NCAA Basketball season.

# %%
similar_games[16450]
# Out:
#        distance  season  weeknum  weekday  hour  winlose  team opponent_team  \
# 16450  0.000000    2017        8        5    18        0   KSU          OKLA
# 5660   0.026194    2014        8        6    24        0   MSU          MICH
# 1434   0.027697    2013        6        1    19        0   YSU          CLEV
# 9751   0.028329    2015       47        5    20        1   MTU          TNST
# 4224   0.035026    2014        2        5    14        1  MIZZ           AUB
# 13568  0.035525    2016       46        5    19        0  NDSU          UNCG
# 10442  0.036333    2015       51        5    23        1   TEX          STAN
# 5509   0.036732    2014        8        2    23        1   UNM          UNLV
# 10960  0.037029    2016        1        5    14        1    NW          MINN
# 8983   0.038010    2015       10        2    19        1  PROV          HALL
# 15518  0.038126    2017        4        5    19        0  HARV          CLMB
# 8067   0.038449    2015        6        1    20        0  NCST          WAKE
# 16358  0.040177    2017        8        3    19        1  UTEP           FAU
# 5983   0.040717    2014       10        3    19        1  VILL           XAV
# 5312   0.040978    2014        7        3    20        1  MORE          JVST
# 2120   0.041655    2013        8        6    18        0   FSU            VT
# 1463   0.044242    2013        6        2    19        0   DEL          TOWS
# 8508   0.044761    2015        7        6    16        0  STAN          COLO
# 4141   0.044871    2014        2        2    21        0   ARK          TXAM
# 8845   0.046534    2015        9        5    14        1  VILL           XAV
#
#        points  opponent_points  points_difference  spread  \
# 16450      51               81                -30    -1.5
# 5660       70               79                 -9    -1.0
# 1434       60               66                 -6    -2.5
# 9751       69               66                  3    -3.0
# 4224       70               68                  2    -1.5
# 13568      54               65                -11    -3.5
# 10442      75               73                  2    -1.0
# 5509       68               56                 12    -1.5
# 10960      77               52                 25    -2.5
# 8983       79               66                 13    -4.0
# 15518      62               65                 -3    -2.5
# 8067       84               88                 -4    -1.0
# 16358      60               55                  5     1.0
# 5983       77               70                  7    -3.5
# 5312       69               67                  2    -3.0
# 2120       70               80                -10    -2.0
# 1463       65               85                -20    -1.0
# 8508       58               64                 -6    -1.5
# 4141       53               69                -16    -2.0
# 8845       78               66                 12    -2.0
#
#        spread_percentage_sbr  moneyline_team  moneyline_opponent  total_team  \
# 16450                     58          -125.0               105.0       138.5
# 5660                      60          -105.0              -105.0       137.5
# 1434                      59          -140.0               130.0       139.0
# 9751                      57          -150.0               140.0       139.5
# 4224                      58          -118.0               108.0       139.5
# 13568                     60          -170.0               150.0       140.0
# 10442                     58          -117.0              -103.0       135.5
# 5509                      56          -118.0               108.0       138.0
# 10960                     61          -140.0               130.0       139.5
# 8983                      57          -170.0               160.0       138.5
# 15518                     58          -130.0               120.0       142.0
# 8067                      57          -113.0               103.0       142.5
# 16358                     59           108.0              -118.0       137.0
# 5983                      56          -160.0               150.0       137.5
# 5312                      59          -150.0               140.0       138.5
# 2120                      58          -135.0               115.0       138.5
# 1463                      57          -117.0              -103.0       137.0
# 8508                      54          -118.0               108.0       136.5
# 4141                      59          -130.0               110.0       139.0
# 8845                      57          -135.0               125.0       142.0
#
#        total_opponent  spread_percentage_sportsplays  spread_percentage_vegas
# 16450           138.5                           67.0                     62.0
# 5660            137.5                           67.0                     64.0
# 1434            139.0                           70.0                     63.0
# 9751            139.5                           68.0                     64.0
# 4224            139.5                           72.0                     62.0
# 13568           140.0                           67.0                     62.0
# 10442           135.5                           68.0                     66.0
# 5509            138.0                           63.0                     64.0
# 10960           139.5                           66.0                     60.0
# 8983            138.5                           69.0                     62.0
# 15518           142.0                           70.0                     64.0
# 8067            142.5                           70.0                     61.0
# 16358           137.0                           68.0                     64.0
# 5983            137.5                           68.0                     59.0
# 5312            138.5                           64.0                     58.0
# 2120            138.5                           61.0                     62.0
# 1463            137.0                           61.0                     62.0
# 8508            136.5                           65.0                     62.0
# 4141            139.0                           69.0                     68.0
# 8845            142.0                           72.0                     64.0

# %%
print('Weighted average points_difference for simillar games', \
      np.average(similar_games[16450].points_difference[1:], weights=similar_games[16450].distance[1:]))
print('Average points_difference for simillar games', \
      np.average(similar_games[16450].points_difference[1:]))
# Out:
# Weighted average points_difference for simillar games -0.185975143349
# Average points_difference for simillar games -0.105263157895

# %%
pl.figure(figsize=[10,10])
x = df.points_difference
y = df.spread
pl.scatter(x, y, c='lightblue', s=5, )
x1 = similar_games[16500].points_difference
y1 = similar_games[16500].spread
pl.scatter(x1, y1, c='red', s=10)
x1 = similar_games[16450].points_difference
y1 = similar_games[16450].spread
pl.scatter(x1, y1, c='black', s=10)
x1 = similar_games[16600].points_difference
y1 = similar_games[16600].spread
pl.scatter(x1, y1, c='green', s=10)
plt.xlim(-50,  40)
plt.ylim(-20, 30)
pl.xlabel('Points difference')
pl.ylabel('Spred')
pl.title('Show on the scatter the nearest games to the given 3 games of 2017 season NCAA Basketball (indices: 16500 (red), 16450 (black), 16600 (green))')
pl.show()

# %%
pl.figure(figsize=[10,10])
x = df.points_difference
y = df.moneyline_team
pl.scatter(x, y, c='lightblue', s=5, )
x1 = similar_games[16500].points_difference
y1 = similar_games[16500].moneyline_team
pl.scatter(x1, y1, c='red', s=10)
x1 = similar_games[16450].points_difference
y1 = similar_games[16450].moneyline_team
pl.scatter(x1, y1, c='black', s=10)
x1 = similar_games[16600].points_difference
y1 = similar_games[16600].moneyline_team
pl.scatter(x1, y1, c='green', s=10)
plt.xlim(-50,  40)
plt.ylim(-1000, 1000)
pl.xlabel('Points difference')
pl.ylabel('Moneyline team')
pl.title('Show on the scatter the nearest games to the given 3 games of 2017 season NCAA Basketball (indices: 16500 (red), 16450 (black), 16600 (green))')
pl.show()

# %% [markdown]
# ## Analysis of timeseries

# %%
filepath = 'seeds/ncaa_movement.csv'

# %%
df_raw = pd.read_csv(filepath)
df = df_raw.drop(['team_org', 'opponent_team_org'], axis=1)
vals = []
df.head()
# Out:
#      casino      date    time  team opponent_team   data_datetime spread_team  \
# 0  pinnacle  20120101  12:00p  RUTG           USF  1/1/2017 12:01       -98.5
# 1  pinnacle  20120101  12:00p  RUTG           USF  1/1/2017 11:44      -101.5
# 2  pinnacle  20120101  12:00p  RUTG           USF  1/1/2017 11:43      -100.5
# 3  pinnacle  20120101  12:00p  RUTG           USF  1/1/2017 11:42      -106.5
# 4  pinnacle  20120101  12:00p  RUTG           USF  1/1/2017 11:42      -104.5
#
#   spread_opponent
# 0           -111.5
# 1           -108.5
# 2           -109.5
# 3             96.5
# 4           -105.5

# %%
#add 24-hour formatted time
new_times = []
for i in df.time:
    if i[-1] == 'a':
        spl = i.split(':')
        h = spl[0]
        m = spl[1][:-1]
        tmp = 12+int(h)
        hour = '00' if tmp == 24 else tmp
        s = str(hour) + ':' + m
        new_times.append(s)
    else:
        new_times.append(i[:-1])
        
df['time'] = new_times
df.head()
# Out:
#      casino      date   time  team opponent_team   data_datetime spread_team  \
# 0  pinnacle  20120101  12:00  RUTG           USF  1/1/2017 12:01       -98.5
# 1  pinnacle  20120101  12:00  RUTG           USF  1/1/2017 11:44      -101.5
# 2  pinnacle  20120101  12:00  RUTG           USF  1/1/2017 11:43      -100.5
# 3  pinnacle  20120101  12:00  RUTG           USF  1/1/2017 11:42      -106.5
# 4  pinnacle  20120101  12:00  RUTG           USF  1/1/2017 11:42      -104.5
#
#   spread_opponent
# 0           -111.5
# 1           -108.5
# 2           -109.5
# 3             96.5
# 4           -105.5

# %%
#correct data_datetmie column (invalid year)
new_data_datetime = []
for d, data in zip(df.date, df.data_datetime):
    year = str(d)[:4]
    pos = data.find('2017')
    if pos == -1:
        pos = data.find('2029')
    new_date = data[:pos] + year + data[pos+4:]
    new_data_datetime.append(new_date)
df['data_datetime'] = new_data_datetime
df.head()
# Out:
#      casino      date   time  team opponent_team   data_datetime spread_team  \
# 0  pinnacle  20120101  12:00  RUTG           USF  1/1/2012 12:01       -98.5
# 1  pinnacle  20120101  12:00  RUTG           USF  1/1/2012 11:44      -101.5
# 2  pinnacle  20120101  12:00  RUTG           USF  1/1/2012 11:43      -100.5
# 3  pinnacle  20120101  12:00  RUTG           USF  1/1/2012 11:42      -106.5
# 4  pinnacle  20120101  12:00  RUTG           USF  1/1/2012 11:42      -104.5
#
#   spread_opponent
# 0           -111.5
# 1           -108.5
# 2           -109.5
# 3             96.5
# 4           -105.5

# %%
#correct data_datetime
timestamps = []
for i in df.data_datetime:
    timestamps.append(int(datetime.strptime(i, '%m/%d/%Y %H:%M').timestamp()))
df['data_datetime'] = timestamps
df.head()
# Out:
#      casino      date   time  team opponent_team  data_datetime spread_team  \
# 0  pinnacle  20120101  12:00  RUTG           USF     1325404860       -98.5
# 1  pinnacle  20120101  12:00  RUTG           USF     1325403840      -101.5
# 2  pinnacle  20120101  12:00  RUTG           USF     1325403780      -100.5
# 3  pinnacle  20120101  12:00  RUTG           USF     1325403720      -106.5
# 4  pinnacle  20120101  12:00  RUTG           USF     1325403720      -104.5
#
#   spread_opponent
# 0           -111.5
# 1           -108.5
# 2           -109.5
# 3             96.5
# 4           -105.5

# %%
#date + time = timestamp
timestamps = []
for d, t in zip(df.date, df.time):
    s = str(d) + ' ' + t
    tmp = int(datetime.strptime(s, '%Y%m%d %H:%M').timestamp())
    timestamps.append(tmp)
df.insert(1, 'timestamp', timestamps)
df.head()
# Out:
#      casino   timestamp      date   time  team opponent_team  data_datetime  \
# 0  pinnacle  1325404800  20120101  12:00  RUTG           USF     1325404860
# 1  pinnacle  1325404800  20120101  12:00  RUTG           USF     1325403840
# 2  pinnacle  1325404800  20120101  12:00  RUTG           USF     1325403780
# 3  pinnacle  1325404800  20120101  12:00  RUTG           USF     1325403720
# 4  pinnacle  1325404800  20120101  12:00  RUTG           USF     1325403720
#
#   spread_team spread_opponent
# 0       -98.5           -111.5
# 1      -101.5           -108.5
# 2      -100.5           -109.5
# 3      -106.5             96.5
# 4      -104.5           -105.5

# %%
df.head()
# Out:
#      casino   timestamp      date   time  team opponent_team  data_datetime  \
# 0  pinnacle  1325404800  20120101  12:00  RUTG           USF     1325404860
# 1  pinnacle  1325404800  20120101  12:00  RUTG           USF     1325403840
# 2  pinnacle  1325404800  20120101  12:00  RUTG           USF     1325403780
# 3  pinnacle  1325404800  20120101  12:00  RUTG           USF     1325403720
# 4  pinnacle  1325404800  20120101  12:00  RUTG           USF     1325403720
#
#   spread_team spread_opponent
# 0       -98.5           -111.5
# 1      -101.5           -108.5
# 2      -100.5           -109.5
# 3      -106.5             96.5
# 4      -104.5           -105.5

# %%
#correct spred (errors like: "PK +115" or "+5 -114")
spread_team = []
for i in df['spread_team']:
    a = float(i.split()[-1])
    spread_team.append(a)
df['spread_team'] = spread_team

spread_opponent = []
for i in df['spread_opponent']:
    a = float(i.split()[-1])
    spread_team.append(a)
df['spread_opponent'] = spread_opponent
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/denilv/anaconda3/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'spread_opponent'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-162-02545ccc4db3> in <module>()
#       7
#       8 spread_opponent = []
# ----> 9 for i in df['spread_opponent']:
#      10     a = float(i.split()[-1])
#      11     spread_team.append(a)
#
# /home/denilv/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /home/denilv/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /home/denilv/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /home/denilv/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/denilv/anaconda3/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'spread_opponent'

# %%
books = set(df.casino)
print('Set of casinos:', books)
